# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-ed806232820c> in <cell line: 1>()
# ----> 1 import pandas as pd
#       2 import matplotlib.pyplot as plt
#       3 import seaborn as sns
#
# /usr/local/lib/python3.10/dist-packages/pandas/__init__.py in <module>
#     136
#     137 from pandas import api, arrays, errors, io, plotting, tseries
# --> 138 from pandas import testing  # noqa:PDF015
#     139 from pandas.util._print_versions import show_versions
#     140
#
# /usr/local/lib/python3.10/dist-packages/pandas/testing.py in <module>
#       4
#       5
# ----> 6 from pandas._testing import (
#       7     assert_extension_array_equal,
#       8     assert_frame_equal,
#
# /usr/local/lib/python3.10/dist-packages/pandas/_testing/__init__.py in <module>
#     901
#     902
# --> 903 cython_table = pd.core.common._cython_table.items()
#     904
#     905
#
# ...

# %%
pip install pandas

# %%
df_2019 = pd.read_csv('merged19_20.csv')
df_2020 = pd.read_csv('merged20_21.csv')
df_2021 = pd.read_csv('merged21_22.csv')
df_2022 = pd.read_csv('merged22_23.csv')
df_2023 = pd.read_csv('merged23_24.csv')
df_all = pd.read_csv('combined_df.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-dadda37459bf> in <cell line: 1>()
# ----> 1 df_2019 = pd.read_csv('merged19_20.csv')
#       2 df_2020 = pd.read_csv('merged20_21.csv')
#       3 df_2021 = pd.read_csv('merged21_22.csv')
#       4 df_2022 = pd.read_csv('merged22_23.csv')
#       5 df_2023 = pd.read_csv('merged23_24.csv')
#
# NameError: name 'pd' is not defined

# %%
selected_columns = ['salary', 'Age', 'GP', 'Min', 'PTS', 'FGM', 'FGA', 'FG%', '3PM', '3PA',
                    '3P%', 'FTM', 'FTA', 'FT%', 'OREB', 'DREB', 'REB', 'AST', 'TOV', 'STL','FP', 'BLK']
selected_df = df_all[selected_columns]

# Create the correlation matrix
correlation_matrix = selected_df.corr()

# Select only the row corresponding to 'salary' for the heatmap
salary_correlation = correlation_matrix.loc[['salary']]

# Plot a heatmap for 'salary' against other columns
plt.figure(figsize=(15, 2))  # Adjust the height based on the number of columns
sns.heatmap(salary_correlation, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Heatmap: Salary vs Other Columns')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-caca9d1d3723> in <cell line: 3>()
#       1 selected_columns = ['salary', 'Age', 'GP', 'Min', 'PTS', 'FGM', 'FGA', 'FG%', '3PM', '3PA',
#       2                     '3P%', 'FTM', 'FTA', 'FT%', 'OREB', 'DREB', 'REB', 'AST', 'TOV', 'STL','FP', 'BLK']
# ----> 3 selected_df = df_all[selected_columns]
#       4
#       5 # Create the correlation matrix
#
# NameError: name 'df_all' is not defined

# %%
sorted_df = df_all.sort_values(by='Player_x')

# %%
player_rows = sorted_df[sorted_df['Player_x'] == 'Andrew Wiggins']
player_rows = player_rows.sort_values(by='season')
import matplotlib.pyplot as plt

# Assuming lu_dort_rows contains your data

fig, ax1 = plt.subplots(figsize=(10, 6))

# Plotting 'salary' on the first y-axis
color = 'tab:red'
ax1.set_xlabel('Season')
ax1.set_ylabel('Salary', color=color)
ax1.plot(player_rows['season'], player_rows['salary'], color=color, marker='o', label='Salary')
ax1.tick_params(axis='y', labelcolor=color)

# Creating a secondary y-axis for 'PTS'
ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('Points (PTS)', color=color)
ax2.plot(player_rows['season'], player_rows['FTA'], color=color, marker='o', label='FTA')
ax2.plot(player_rows['season'], player_rows['FTM'], color='orange', marker='o', label='FTM')
ax2.tick_params(axis='y', labelcolor=color)

# Adding labels and title
plt.title('Salary, FTA, and FTM Over Seasons for Andrew Wiggins')

# Display the legend
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# Display the plot
plt.show()

# %%
player_rows = sorted_df[sorted_df['Player_x'] == 'Jordan Poole']
player_rows = player_rows.sort_values(by='season')
fig, ax1 = plt.subplots(figsize=(10, 6))

# Plotting 'salary' on the first y-axis
color = 'tab:red'
ax1.set_xlabel('Season')
ax1.set_ylabel('Salary', color=color)
ax1.plot(player_rows['season'], player_rows['salary'], color=color, marker='o')
ax1.tick_params(axis='y', labelcolor=color)

# Creating a secondary y-axis for 'PTS'
ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('Points (PTS)', color=color)
ax2.plot(player_rows['season'], player_rows['PTS'], color=color, marker='o')
ax2.tick_params(axis='y', labelcolor=color)

# Adding labels and title
plt.title('Salary and Points (PTS) Over Seasons for Jordan Poole')

# Display the plot
# Out:
# Text(0.5, 1.0, 'Salary and Points (PTS) Over Seasons for Jordan Poole')
